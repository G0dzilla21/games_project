# %% [markdown]
# ### Cody's Rock, Paper, Scissors Game

# %%
def rps_start(): 

    import random

    replay1 = "1" #set replays to 1 so loop can run for the first time
    replay2 = "1" 
    wins1 = 0
    wins2 = 0
    draws = 0
    players = 0
    computer = 0
    user = 0

    players = input("How many players (1 or 2): ")

    while (players != "1" and players != "2"):
        players = input("Invalid input! How many players (1 or 2): ")


    def rps_multiplayer():
        
        #start of game loop with 2 players
        while players == "2" and replay1 == "1":

            user1 = input("User 1: Enter 'r' for rock, 'p' for paper, or 's' for scissors: ") 
            while (user1 != "r" and user1 != "p" and user1 != "s"): #ensuring the user's input is correct
                user1 = input("That is not a valid input, please re-enter: ")

            user2 = input("User 2: Enter 'r' for rock, 'p' for paper, or 's' for scissors: ") 
            while (user2 != "r" and user2 != "p" and user2 != "s"): #ensuring the user's input is correct
                user2 = input("That is not a valid input, please re-enter: ")    

            #first compare the two objects to see if there is a draw    
            if user1 == user2:
                print("Draw!")
                draws += 1
            #next compare the 3 different case scenarios    
            elif (user1 == "r") & (user2 == "p"):
                print("User 2 wins!")
                wins2 += 1
            elif (user1 == "p") & (user2 == "s"):
                print("User 2 wins!")
                wins2 += 1
            elif (user1 == "s") & (user2 == "r"):
                print("User 2 wins!")
                wins2 += 1
            #if it's none of the above cases, user 1 must win    
            else:
                print("User 1 wins!")
                wins1 += 1

            replay1 = input("Would you like to play again? 1 for yes, 2 for no: ") #asking to play again
            while replay1 != "1" and replay1 != "2": #ensuring the user's input is correct
                print("Invalid input.")
                replay1 = input("Would you like to play again? 1 for yes, 2 for no: ") 



    while players == "1" and replay2 == "1":

        user = input("User 1: Enter 'r' for rock, 'p' for paper, or 's' for scissors: ") 
        while (user != "r" and user != "p" and user != "s"): #ensuring the user's input is correct
            user = input("That is not a valid input, please re-enter: ")

        computer = random.randrange(1, 4)  #this block gets a random number 1-3 and assigns it to computer
        if computer == 1:                  #then assigning computer a character (r,p,s) based off the random number
            computer = 'r'
        elif computer == 2:
            computer = 'p'
        else: 
            computer == 's'

        #first compare the two objects to see if there is a draw and add to total draws   
        if user == computer:
            print("Draw!")
            draws += 1
        #next compare the 3 different case scenarios and add to total wins for that winner    
        elif (user == "r") & (computer == "p"):
            print("Computer wins!")
            wins2 += 1
        elif (user == "p") & (computer == "s"):
            print("Computer wins!")
            wins2 += 1
        elif (user == "s") & (computer == "r"):
            print("computer wins!")
            wins2 += 1
        #if it's none of the above cases, user 1 must win    
        else:
            print("User 1 wins!")
            wins1 += 1    

        replay2 = input("Would you like to play again? 1 for yes, 2 for no: ") #asking to play again
        while replay2 != "1" and replay2 != "2": #ensuring the user's input is correct
            print("Invalid input.")
            replay2 = input("Would you like to play again? 1 for yes, 2 for no: ")

    #printing out game(s) results        
    if players == "2":
        print("/nThanks for playing!")
        print("Draws: ", draws)
        print("User 1 Wins: ", wins1)
        print("User 2 Wins: ", wins2)

    if players == "1":
        print("/nThanks for playing!")
        print("Draws: ", draws)
        print("User Wins: ", wins1)
        print("Computer Wins: ", wins2)
    
    menu = input("/nWould you like to go back to the main menu? 1 for yes, 2 for no: ")
    while menu != "1" and menu != "2": #ensuring the user's input is correct
            print("Invalid input.")
            menu = input("/nWould you like to go back to the main menu? 1 for yes, 2 for no: ")
    if menu == "1":
        main()
# Out:
# Welcome to the game menu! Please choose one of the following:
#
# 1. Rock, Paper, Scissors
# Please make a selection: 1
# How many players (1 or 2): 1
# User 1: Enter 'r' for rock, 'p' for paper, or 's' for scissors: r
# User 1 wins!
# Would you like to play again? 1 for yes, 2 for no: p
# Invalid input.
# Would you like to play again? 1 for yes, 2 for no: 1
# User 1: Enter 'r' for rock, 'p' for paper, or 's' for scissors: r
# Computer wins!
# Would you like to play again? 1 for yes, 2 for no: 2
# Thanks for playing!
# Draws:  0
# User Wins:  1
# Computer Wins:  1
#
# Would you like to go back to the main menu? 1 for yes, 2 for no: 1
